# %% [markdown]
# ## Project 2 Starting Over
# Jacob Minkin
# Last project I tried to predict a critical violation from location and cuisine. The problem is that almost all restaurants have at least one critical violation which made it hard to get any predictive value from the model. Now I want to try again with predicting the score and therefore grade of the restaurant

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from sklearn.impute import KNNImputer
sns.set_style('darkgrid')

#Import Data
df = pd.read_csv('../data/Inspection.csv')
df['date'] = pd.to_datetime(df['INSPECTION DATE'])

# %% [markdown]
# ## Find most recent score for every restaurant

# %%
df.SCORE.hist()
# Out:
# <AxesSubplot:>

# %%
df.sort_values(['date'], ascending=False, inplace= True)
df_recent = df.groupby(['CAMIS'], sort=False).first()

# %%
df_recent.SCORE.hist()
(df_recent[df_recent.SCORE == 0])
# Out:
#                                   DBA       BORO BUILDING  \
# CAMIS
# 40535738           NEIL SIMON THEATRE  Manhattan      250
# 50130587          ST. FRANCIS COLLEGE   Brooklyn      179
# 50019120                    NEW TOPAZ  Manhattan      127
# 50084290            ARIA WEST VILLAGE  Manhattan    14-16
# 41531136        AUGUST WILSON THEATRE  Manhattan      245
# ...                               ...        ...      ...
# 50044522                   CLUB GRILL  Manhattan        4
# 50074493                PINKY'S SPACE  Manhattan       70
# 50002397  CIBO EXPRESS GOURMET MARKET     Queens        0
# 50002422                     TAGLIERE     Queens     None
# 41644180        MANHATTAN TERRACE BAR     Queens   110-00
#
#                              STREET  ZIPCODE       PHONE   CUISINE  \
# CAMIS
# 40535738           WEST   52 STREET  10019.0  2123544624  American
# 50130587              LIVINGSTON ST  11201.0  7184092070  American
# 50019120           WEST   56 STREET  10019.0  2129578020      Thai
# 50084290             BEDFORD STREET  10014.0  2122424233   Italian
# 41531136           WEST   52 STREET  10019.0  2125825472  American
# ...                             ...      ...         ...       ...
# 50044522                   PENN PLZ  10121.0  2124656273  American
# 50074493           EAST    1 STREET  10003.0  5127896128     Other
# 50002397      JFK INTERNATIONAL LLC  11430.0  2159970667  American
# 50002422  JFK INTERNATIONAL AIRPORT  11430.0  6464835087     Pizza
# 41644180         ROCKAWAY BOULEVARD  11420.0  2122153542  American
#
#          INSPECTION DATE                                             ACTION  \
# CAMIS
# 40535738        2/8/2023  No violations were recorded at the time of thi...
# 50130587        2/6/2023  No violations were recorded at the time of thi...
# 50019120        2/3/2023    Violations were cited in the following area(s).
# 50084290        2/2/2023                  Establishment re-opened by DOHMH.
# 41531136        2/1/2023  No violations were recorded at the time of thi...
# ...                  ...                                                ...
# 50044522       5/30/2019  No violations were recorded at the time of thi...
# 50074493       5/18/2019  No violations were recorded at the time of thi...
# 50002397       5/16/2019  No violations were recorded at the time of thi...
# 50002422       5/16/2019  No violations were recorded at the time of thi...
# 41644180        6/8/2018  No violations were recorded at the time of thi...
#
#          VIOLATION CODE  ...        BIN           BBL   NTA Location Point  \
# CAMIS                    ...
# 40535738           None  ...  1024820.0  1.010230e+09  MN17            NaN
# 50130587           None  ...        NaN  3.000000e+00  BK38            NaN
# 50019120          20-06  ...  1023453.0  1.010090e+09  MN17            NaN
# 50084290          20-08  ...  1008347.0  1.005270e+09  MN23            NaN
# 41531136           None  ...  1024826.0  1.010240e+09  MN17            NaN
# ...                 ...  ...        ...           ...   ...            ...
# 50044522            02B  ...  1082908.0  1.007810e+09  MN17            NaN
# 50074493            10F  ...  1006099.0  1.004430e+09  MN22            NaN
# 50002397            10F  ...  4542156.0  4.142600e+09  QN98            NaN
# 50002422            10F  ...        NaN           NaN  None            NaN
# 41644180           None  ...  4457718.0  4.115430e+09  QN55            NaN
#
#          Zip Codes Community Districts Borough Boundaries  \
# CAMIS
# 40535738       NaN                 NaN                NaN
# 50130587       NaN                 NaN                NaN
# 50019120       NaN                 NaN                NaN
# 50084290       NaN                 NaN                NaN
# 41531136       NaN                 NaN                NaN
# ...            ...                 ...                ...
# 50044522       NaN                 NaN                NaN
# 50074493       NaN                 NaN                NaN
# 50002397       NaN                 NaN                NaN
# 50002422       NaN                 NaN                NaN
# 41644180       NaN                 NaN                NaN
#
#           City Council Districts  Police Precincts       date
# CAMIS
# 40535738                     NaN               NaN 2023-02-08
# 50130587                     NaN               NaN 2023-02-06
# 50019120                     NaN               NaN 2023-02-03
# 50084290                     NaN               NaN 2023-02-02
# 41531136                     NaN               NaN 2023-02-01
# ...                          ...               ...        ...
# 50044522                     NaN               NaN 2019-05-30
# 50074493                     NaN               NaN 2019-05-18
# 50002397                     NaN               NaN 2019-05-16
# 50002422                     NaN               NaN 2019-05-16
# 41644180                     NaN               NaN 2018-06-08
#
# [1082 rows x 32 columns]

# %%
df_recent[df_recent.ACTION == 'No violations were recorded at the time of this inspection.']
# Out:
#                              DBA       BORO BUILDING  \
# CAMIS
# 41267566           SMITH & MILLS  Manhattan       71
# 50111280    PLANTSHED COFFEE BAR  Manhattan      723
# 50080435      FULKOLE RESTAURANT   Brooklyn     1211
# 40535738      NEIL SIMON THEATRE  Manhattan      250
# 50130587     ST. FRANCIS COLLEGE   Brooklyn      179
# ...                          ...        ...      ...
# 50002422                TAGLIERE     Queens     None
# 41534086  LA PIZZA & CONVENIENCE   Brooklyn      887
# 40483596        GERSHWIN THEATRE  Manhattan      222
# 50076292               1 QUETZAL   Brooklyn     7210
# 41644180   MANHATTAN TERRACE BAR     Queens   110-00
#
#                              STREET  ZIPCODE       PHONE      CUISINE  \
# CAMIS
# 41267566         NORTH MOORE STREET  10013.0  2122262515     American
# 50111280           AMSTERDAM AVENUE  10025.0  2126624400   Coffee/Tea
# 50080435             LIBERTY AVENUE  11208.0  9173536405  Bangladeshi
# 40535738           WEST   52 STREET  10019.0  2123544624     American
# 50130587              LIVINGSTON ST  11201.0  7184092070     American
# ...                             ...      ...         ...          ...
# 50002422  JFK INTERNATIONAL AIRPORT  11430.0  6464835087        Pizza
# 41534086           MANHATTAN AVENUE  11222.0  7183830666        Pizza
# 40483596           WEST   51 STREET  10019.0  2123544624        Other
# 50076292         NEW UTRECHT AVENUE  11228.0  9296669989      Mexican
# 41644180         ROCKAWAY BOULEVARD  11420.0  2122153542     American
#
#          INSPECTION DATE                                             ACTION  \
# CAMIS
# 41267566        2/9/2023  No violations were recorded at the time of thi...
# 50111280        2/9/2023  No violations were recorded at the time of thi...
# 50080435        2/9/2023  No violations were recorded at the time of thi...
# 40535738        2/8/2023  No violations were recorded at the time of thi...
# 50130587        2/6/2023  No violations were recorded at the time of thi...
# ...                  ...                                                ...
# 50002422       5/16/2019  No violations were recorded at the time of thi...
# 41534086        5/1/2019  No violations were recorded at the time of thi...
# 40483596      10/23/2018  No violations were recorded at the time of thi...
# 50076292       9/28/2018  No violations were recorded at the time of thi...
# 41644180        6/8/2018  No violations were recorded at the time of thi...
#
#          VIOLATION CODE  ...        BIN           BBL   NTA Location Point  \
# CAMIS                    ...
# 41267566           None  ...  1002123.0  1.001880e+09  MN24            NaN
# 50111280            06C  ...  1032587.0  1.012268e+09  MN12            NaN
# 50080435            02H  ...  3094137.0  3.041840e+09  BK83            NaN
# 40535738           None  ...  1024820.0  1.010230e+09  MN17            NaN
# 50130587           None  ...        NaN  3.000000e+00  BK38            NaN
# ...                 ...  ...        ...           ...   ...            ...
# 50002422            10F  ...        NaN           NaN  None            NaN
# 41534086            22C  ...  3064834.0  3.025630e+09  BK76            NaN
# 40483596            20D  ...  1024812.0  1.010220e+09  MN17            NaN
# 50076292            10F  ...  3158364.0  3.061910e+09  BK28            NaN
# 41644180           None  ...  4457718.0  4.115430e+09  QN55            NaN
#
#          Zip Codes Community Districts Borough Boundaries  \
# CAMIS
# 41267566       NaN                 NaN                NaN
# 50111280       NaN                 NaN                NaN
# 50080435       NaN                 NaN                NaN
# 40535738       NaN                 NaN                NaN
# 50130587       NaN                 NaN                NaN
# ...            ...                 ...                ...
# 50002422       NaN                 NaN                NaN
# 41534086       NaN                 NaN                NaN
# 40483596       NaN                 NaN                NaN
# 50076292       NaN                 NaN                NaN
# 41644180       NaN                 NaN                NaN
#
#           City Council Districts  Police Precincts       date
# CAMIS
# 41267566                     NaN               NaN 2023-02-09
# 50111280                     NaN               NaN 2023-02-09
# 50080435                     NaN               NaN 2023-02-09
# 40535738                     NaN               NaN 2023-02-08
# 50130587                     NaN               NaN 2023-02-06
# ...                          ...               ...        ...
# 50002422                     NaN               NaN 2019-05-16
# 41534086                     NaN               NaN 2019-05-01
# 40483596                     NaN               NaN 2018-10-23
# 50076292                     NaN               NaN 2018-09-28
# 41644180                     NaN               NaN 2018-06-08
#
# [245 rows x 32 columns]

# %%
df[['CAMIS','GRADE','SCORE', 'date']].loc[df.DBA == 'LA PIZZA & CONVENIENCE']
# Out:
#            CAMIS GRADE  SCORE       date
# 142464  41534086   NaN    NaN 2019-05-01
# 24100   41534086     A   11.0 2019-05-01
# 201875  41534086     A   11.0 2019-05-01
# 3170    41534086     A   11.0 2019-05-01
# 77494   41534086     A   13.0 2018-12-18
# 11567   41534086     A   13.0 2018-12-18
# 99483   41534086     A   13.0 2018-12-18
# 111741  41534086   NaN   30.0 2018-11-28
# 34686   41534086   NaN   30.0 2018-11-28
# 115965  41534086   NaN   30.0 2018-11-28
# 98898   41534086   NaN   30.0 2018-11-28
# 61316   41534086   NaN   30.0 2018-11-28
# 41353   41534086     A   12.0 2017-12-04
# 42060   41534086     A   12.0 2017-12-04
# 209240  41534086     A   12.0 2017-12-04
# 194797  41534086     A    4.0 2017-05-03
# 134823  41534086     A    4.0 2017-05-03
# 175173  41534086   NaN   22.0 2017-03-30
# 98138   41534086   NaN   22.0 2017-03-30
# 204281  41534086   NaN   22.0 2017-03-30
# 171867  41534086   NaN   22.0 2017-03-30
# 48779   41534086   NaN   22.0 2017-03-30

# %%
df_recent[['GRADE','SCORE', 'date']].loc[df_recent.DBA == 'LA PIZZA & CONVENIENCE']
# Out:
#          GRADE  SCORE       date
# CAMIS
# 41534086     A   11.0 2019-05-01

# %%
df_recent.DBA[df_recent.GRADE.isna()]
# Out:
# CAMIS
# 50094469                   REVOLVER
# 50131837              SQUARE COFFEE
# 50107767                       None
# 50109856        THE LATE NIGHT CAFE
# 50131536    MARRON PASTRY MANHATTAN
#                      ...
# 50119778                       None
# 50131312             167 PIZZA CAFE
# 50131515                       None
# 50123260        LITTLE NECK KITCHEN
# 50107551                     Zazzys
# Name: DBA, Length: 4358, dtype: object

# %%
df_unranked = df[df['INSPECTION DATE'] == '1/1/1900']

# %%
df_recent = df_recent[df_recent['INSPECTION DATE'] != '1/1/1900']

# %%
df_recent.SCORE.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Average Score for Boro

# %%
df_recent.groupby('BORO')['SCORE'].mean()
# Out:
# BORO
# 0                 7.600000
# Bronx            13.941626
# Brooklyn         13.301499
# Manhattan        12.949240
# Queens           13.814399
# Staten Island    13.096559
# Name: SCORE, dtype: float64

# %%
df_recent.BORO.sort_values()
# Out:
# CAMIS
# 50060598                0
# 50005134                0
# 50005059                0
# 40883586                0
# 50049804                0
#                 ...
# 41305175    Staten Island
# 50101351    Staten Island
# 40807238    Staten Island
# 50108541    Staten Island
# 50002463    Staten Island
# Name: BORO, Length: 23881, dtype: object

# %%
df[df.BORO == '0']
# Out:
#            CAMIS                                                DBA BORO  \
# 133298  40883586                            FLIK (American Express)    0
# 189952  50005059                                           FREEHOLD    0
# 91343   50005059                                           FREEHOLD    0
# 31020   50005059                                           FREEHOLD    0
# 52218   50060598  POKEWORKS (Entrance is on 41st street between ...    0
# ...          ...                                                ...  ...
# 110831  50125174                                                NaN    0
# 1018    50123437                                                NaN    0
# 116663  50112993                                                NaN    0
# 118094  50115150                                                NaN    0
# 1049    50107999                  HALAL AMERICAN BEST CHICKEN WINGS    0
#
#        BUILDING        STREET  ZIPCODE       PHONE   CUISINE INSPECTION DATE  \
# 133298      200  VESEY STREET  10285.0  2126405562  American       11/1/2022
# 189952       45      S 3RD ST  11249.0  7183887591  American       5/25/2022
# 91343        45      S 3RD ST  11249.0  7183887591  American       5/25/2022
# 31020        45      S 3RD ST  11249.0  7183887591  American       5/25/2022
# 52218       122     E 42ND ST  10168.0  6466539793  Hawaiian        4/4/2022
# ...         ...           ...      ...         ...       ...             ...
# 110831      NaN           NaN      NaN  9177053204       NaN        1/1/1900
# 1018        274  ATLANTIC AVE  11518.0  9176809065       NaN        1/1/1900
# 116663      NaN           NaN      NaN    72283779       NaN        1/1/1900
# 118094      NaN           NaN      NaN  3473618178       NaN        1/1/1900
# 1049        959     NASSAU RD  11553.0  3477509185       NaN        1/1/1900
#
#                                                  ACTION  ... BIN BBL  NTA  \
# 133298  Violations were cited in the following area(s).  ... NaN NaN  NaN
# 189952  Violations were cited in the following area(s).  ... NaN NaN  NaN
# 91343   Violations were cited in the following area(s).  ... NaN NaN  NaN
# 31020   Violations were cited in the following area(s).  ... NaN NaN  NaN
# 52218   Violations were cited in the following area(s).  ... NaN NaN  NaN
# ...                                                 ...  ...  ..  ..  ...
# 110831                                              NaN  ... NaN NaN  NaN
# 1018                                                NaN  ... NaN NaN  NaN
# 116663                                              NaN  ... NaN NaN  NaN
# 118094                                              NaN  ... NaN NaN  NaN
# 1049                                                NaN  ... NaN NaN  NaN
#
#         Location Point Zip Codes Community Districts Borough Boundaries  \
# 133298             NaN       NaN                 NaN                NaN
# 189952             NaN       NaN                 NaN                NaN
# 91343              NaN       NaN                 NaN                NaN
# 31020              NaN       NaN                 NaN                NaN
# 52218              NaN       NaN                 NaN                NaN
# ...                ...       ...                 ...                ...
# 110831             NaN       NaN                 NaN                NaN
# 1018               NaN       NaN                 NaN                NaN
# 116663             NaN       NaN                 NaN                NaN
# 118094             NaN       NaN                 NaN                NaN
# 1049               NaN       NaN                 NaN                NaN
#
#        City Council Districts  Police Precincts       date
# 133298                    NaN               NaN 2022-11-01
# 189952                    NaN               NaN 2022-05-25
# 91343                     NaN               NaN 2022-05-25
# 31020                     NaN               NaN 2022-05-25
# 52218                     NaN               NaN 2022-04-04
# ...                       ...               ...        ...
# 110831                    NaN               NaN 1900-01-01
# 1018                      NaN               NaN 1900-01-01
# 116663                    NaN               NaN 1900-01-01
# 118094                    NaN               NaN 1900-01-01
# 1049                      NaN               NaN 1900-01-01
#
# [78 rows x 33 columns]
